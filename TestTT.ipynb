# %%
import matplotlib.pyplot as plt
import numpy as np
import sys

# %%
sys.path.insert(0, '/home/jovyan/EOSC471/2024W1/ttide_py/ttide_py-master')

# %%
import ttide as tt

# %%
t = np.arange(1001)
m2_freq = 2 * np.pi / 12.42

# %%
elev = 5 * np.cos(m2_freq * t)

# %%
tfit_e = tt.t_tide(elev);
# Out:
# -----------------------------------
# nobs = 1001
# ngood = 1001
# record length (days) = 41.71
# rayleigh criterion = 1.0
#
# Phases at central time
# x0= 3.66e-06  xtrend= 0
# var(data)= 12.53    var(prediction)= 12.53    var(residual)= 0.00
# var(prediction)/var(data) (%) = 100.0
#
#         tidal amplitude and phase with 95 % CI estimates
#  tide      freq        amp      amp_err   pha      pha_err    snr
#   MM    0.0015122     0.0004     0.000     89.79     65.90       1.1
#   MSF   0.0028219     0.0001     0.000    266.87    153.00      0.15
#   ALP1  0.0343966     0.0004     0.000    269.34     49.74       1.3
#   2Q1   0.0357064     0.0004     0.000     88.36     43.44         2
#   Q1    0.0372185     0.0003     0.000     89.82     69.00       0.7
#   O1    0.0387307     0.0004     0.000    268.05     47.76       1.9
#   NO1   0.0402686     0.0004     0.000    269.19     44.48       1.9
#   K1    0.0417807     0.0004     0.000     87.64     57.02       1.7
# ...

# %%
elev_fit = tfit_e(t)
# Out:
# /home/jovyan/EOSC471/2024W1/ttide_py/ttide_py-master/ttide/t_getconsts.py:81: RuntimeWarning: invalid value encountered in cast
#   shallow_m1 = const['ishallow'].astype(int) -1

# %%
plt.plot(elev[0:48])
plt.plot(elev_fit[0:48])
